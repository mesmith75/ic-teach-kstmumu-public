# %%
import json
import pandas
pandas.set_option("display.latex.repr",False)
import matplotlib

# %%
si_preds = {}
pi_preds = {}
with open("std_predictions_si.json","r") as _f:
    si_preds = json.load(_f)
with open("std_predictions_pi.json","r") as _f:
    pi_preds = json.load(_f)

# %%
from IPython.display import display, HTML
for _binNo in si_preds.keys():
    print('Bin number %s' % _binNo)
    si_frame = pandas.DataFrame(si_preds[_binNo]).transpose()
    display(HTML(pandas.DataFrame(si_frame).to_html()))
# Out:
# Bin number 0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>val</th>
#       <th>err</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>FL</th>
#       <td>0.296448</td>
#       <td>0.050642</td>
#     </tr>
#     <tr>
#       <th>AFB</th>
#       <td>-0.097052</td>
#       <td>0.008421</td>
#     </tr>
#     <tr>
#       <th>S3</th>
#       <td>0.010876</td>
#       <td>0.006028</td>
#     </tr>
#     <tr>
#       <th>S4</th>
#       <td>0.090919</td>
#       <td>0.006011</td>
#     </tr>
#     <tr>
#       <th>S5</th>
#       <td>0.252907</td>
#       <td>0.010621</td>
#     </tr>
#     <tr>
#       <th>S7</th>
#       <td>-0.020672</td>
#       <td>0.016901</td>
#     </tr>
#     <tr>
#       <th>S8</th>
#       <td>-0.002153</td>
#       <td>0.009466</td>
#     </tr>
#     <tr>
#       <th>S9</th>
#       <td>-0.000701</td>
#       <td>0.007420</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
for _binNo in pi_preds.keys():
    print('Bin number %s' % _binNo)
    pi_frame = pandas.DataFrame(pi_preds[_binNo]).transpose()
    display(HTML(pandas.DataFrame(pi_frame).to_html()))
# Out:
# Bin number 0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>val</th>
#       <th>err</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>FL</th>
#       <td>0.296448</td>
#       <td>0.050677</td>
#     </tr>
#     <tr>
#       <th>P1</th>
#       <td>0.044322</td>
#       <td>0.030087</td>
#     </tr>
#     <tr>
#       <th>P2</th>
#       <td>-0.131839</td>
#       <td>0.008365</td>
#     </tr>
#     <tr>
#       <th>P3</th>
#       <td>0.001429</td>
#       <td>0.010774</td>
#     </tr>
#     <tr>
#       <th>P4p</th>
#       <td>0.238368</td>
#       <td>0.014234</td>
#     </tr>
#     <tr>
#       <th>P5p</th>
#       <td>0.663060</td>
#       <td>0.026813</td>
#     </tr>
#     <tr>
#       <th>P6p</th>
#       <td>-0.054197</td>
#       <td>0.037855</td>
#     </tr>
#     <tr>
#       <th>P8p</th>
#       <td>-0.005646</td>
#       <td>0.023612</td>
#     </tr>
#   </tbody>
# </table>
# ...
